# %%
def read_loss_data(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
        train_loss_history = list(map(float, lines[0].split('\t')))
        test_loss_history = list(map(float, lines[1].split('\t')))
    return train_loss_history, test_loss_history

# %%
import matplotlib.pyplot as plt

# Assume 'filename' is the path to your text file
# filename = "learn_rate_change_lr_0.003.txt"  # Change the filename to your specific file
# train_loss_history1, test_loss_history1 = read_loss_data(filename)

# filename = "learn_rate_change_lr_0.005.txt"  # Change the filename to your specific file
# train_loss_history2, test_loss_history2 = read_loss_data(filename)

# train_loss_history = train_loss_history1 + train_loss_history2
# test_loss_history = test_loss_history1 + test_loss_history2

filename = "learn_rate_const_lr_0.004.txt"  # Change the filename to your specific file
train_loss_history, test_loss_history = read_loss_data(filename)
# Plotting code
plt.plot(range(60), train_loss_history, '-', linewidth=3, label='Train error')
plt.plot(range(60), test_loss_history, '-', linewidth=3, label='Test error')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid(True)
plt.legend()
plt.show()
